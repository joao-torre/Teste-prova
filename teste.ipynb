# %% [markdown]
# # Projeto Genesys
#
#    ### CR

# %% [markdown]
# ### CAL

# %%
import requests
import json
import PureCloudPlatformClientV2
from PureCloudPlatformClientV2.rest import ApiException
from pprint import pprint
import base64

# Configurações do OAuth
client_id = "fba734fe-c75e-4a04-a0f9-c82557b5a1de"
client_secret = "s5ut4GLMpjZwU1XS9AScJU-Hg8snlYMz44BeSqM-XvI"
encodedData = base64.b64encode(bytes(f"{client_id}:{client_secret}", "ISO-8859-1")).decode("ascii")
authorization_header_string = f"Basic {encodedData}"

access_token_url = "https://login.sae1.pure.cloud/oauth/token"
response = requests.post(access_token_url, headers={"Authorization": authorization_header_string}, data={'grant_type': 'client_credentials'})
access_token = response.json()['access_token']
print("Access token obtained successfully:", access_token)

headers = {
    'Authorization': f"Bearer {access_token}",
    'Content-Type': 'application/json'
}

body = {
        "timeZone": "Américas/São Paulo",
    "exportFormat": "CSV",
    "period": "P1D",
    "viewType": "QUEUE_PERFORMANCE_SUMMARY_VIEW",
    "filter": {
        "mediaTypes":[
            "voice"
        ],
        "queueIds": [
            "e4ed22cc-5878-46bd-a0c2-4d7fb20c0a15",
            "e3710d34-a7a5-44e6-8ed7-dd0c1d6ab77f",
            "518a0be0-d565-4057-bf4b-772ffe82c6b7",
            "67a86f91-ef50-44b9-b213-32cf3e6b0dd7",
            "a1969be7-c9a5-43f3-80c0-254d592e6747",
            "cd18f80a-0c6e-42b5-851b-4eed80ec0dff",
            "d3f23a97-7afc-4599-bae6-18143d721fd1",
            "77c94ac0-4de0-4bc8-8106-98b956fbb267",
            "431937e6-c98d-451f-8d1f-91d456590463",
            "7ecab67a-b007-4be7-af8c-cf0bc60c8366",
            "486e22d5-370e-4f12-8b64-c2283a8e89ee",
            "d60972a8-d6cc-49b0-870c-7b521cde7ffc",
            "0ed0b06a-02d7-4cdf-bf1b-7ab2cfb77ce8",
            "59b75ff9-0a74-463e-aeb0-8d8f8e614bad",
            "e80610c7-eb64-4392-baaa-cdf22d7ca994",
            "b1a85d5c-0590-4093-83db-ddf8cb4a3383",
            "8969ec82-deb9-4d61-9f0e-891345761e41",
            "8497766b-932c-4d78-8744-3f3e49c19433",
            "a71ae90d-0e2d-4cc9-967c-39fd3a3a8dc6",
            "09d07962-6337-4523-889c-cc15c378be37"
        ],
        "directions": [
            "inbound"
        ],
        "evaluationScore": {
            "gt": 0,
            "gte": 0,
            "lt": 0,
            "lte": 0
        },
        "evaluationCriticalScore": {
            "gt": 0,
            "gte": 0,
            "lt": 0,
            "lte": 0
        },
        "surveyTotalScore": {
            "gt": 0,
            "gte": 0,
            "lt": 0,
            "lte": 0
        },
        "surveyNpsScore": {
            "gt": 0,
            "gte": 0,
            "lt": 0,
            "lte": 0
        },
        "mos": {
            "gt": 0,
            "gte": 0,
            "lt": 0,
            "lte": 0
        },
        "surveyQuestionGroupScore": {
            "gt": 0,
            "gte": 0,
            "lt":0,
            "lte": 0
        },
        "surveyPromoterScore": {
            "gt": 0,
            "gte": 0,
            "lt": 0,
            "lte": 0
        },
        "isCampaign": True,
        "callbackInterval": "",
        "customerSentimentScore": {
            "gt": 100,
            "gte": 100,
            "lt": 100,
            "lte": 100
        },
        "customerSentimentTrend": {
            "gt": 0,
            "gte": 0,
            "lt": 0,
            "lte": 0
        },
        "developmentName": "",
        "botProviderList": [
            "Genesys"
        ],
        "actionCategoryName": "",
        "availableDashboard": "Private",
        "favouriteDashboard": True,
        "myDashboard": True,
        "subPath": "",
        "userState": "ActiveAndInactive",
        "divisionIds": [
            "f6cbd444-0b16-463e-a7b7-38a8b03a8562"
        ],
        "originatingDirections": [
            "inbound"
        ],
        "transferred": True,
        "abandoned": True,
        "answered": True
    },
    "locale": "pt-BR",
    "csvDelimiter": "SEMICOLON",
    "durationFormat": "Hhmmss",
    "name": "03-07-2024 Summary view",
    "interval": "2024-03-07T00:00:00/2024-03-07T23:59:00",
    "includeDurationFormatInHeader": True,
    "hasSummaryRow": True,
    "hasFormatDurations": True
}

# Configurações da API
analytics_api_base_url = "https://api.mypurecloud.com"
analytics_api_path = "/api/v2/analytics/reporting/exports"

api_instance = PureCloudPlatformClientV2.AnalyticsApi()

try:
    api_response = api_instance.post_analytics_reporting_exports(body, headers=headers)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling AnalyticsApi->post_analytics_reporting_exports: %s\n" % e)
# Out:
# Access token obtained successfully: GISpgm6QqkDbbMl1SHMBDE67miBNbunkSjwkE9PF3IVuG3v-b7FErsll777GEoNoER6Krhz4YuaObUq7RtApBg
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 151
#     148 api_instance = PureCloudPlatformClientV2.AnalyticsApi()
#     150 try:
# --> 151     api_response = api_instance.post_analytics_reporting_exports(body, headers=headers)
#     152     pprint(api_response)
#     153 except ApiException as e:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\PureCloudPlatformClientV2\apis\analytics_api.py:6383, in AnalyticsApi.post_analytics_reporting_exports(self, body, **kwargs)
#    6381 for key, val in iteritems(params['kwargs']):
#    6382     if key not in all_params:
# -> 6383         raise TypeError(
#    6384             "Got an unexpected keyword argument '%s'"
#    6385             " to method post_analytics_reporting_exports" % key
# ...

# %%
import requests
import json
import base64
from pprint import pprint

def get_access_token(client_id, client_secret):
    access_token_url = "https://login.sae1.pure.cloud/oauth/token"
    encoded_data = base64.b64encode(bytes(f"{client_id}:{client_secret}", "ISO-8859-1")).decode("ascii")
    authorization_header = f"Basic {encoded_data}"
    response = requests.post(access_token_url, headers={"Authorization": authorization_header}, data={'grant_type': 'client_credentials'})
    if response.status_code == 200:
        return response.json()['access_token']
    else:
        print(f"Failed to obtain access token: {response.status_code}")
        return None

def export_report(access_token):
    api_url = "https://api.mypurecloud.com/api/v2/analytics/reporting/exports"
    headers = {"Authorization": f"Bearer {access_token}", 'Content-Type': 'application/json'}
    body = {
        "timeZone": "Américas/São Paulo",
    "exportFormat": "CSV",
    "period": "P1D",
    "viewType": "QUEUE_PERFORMANCE_SUMMARY_VIEW",
    "filter": {
        "mediaTypes":[
            "voice"
        ],
        "queueIds": [
            "e4ed22cc-5878-46bd-a0c2-4d7fb20c0a15",
            "e3710d34-a7a5-44e6-8ed7-dd0c1d6ab77f",
            "518a0be0-d565-4057-bf4b-772ffe82c6b7",
            "67a86f91-ef50-44b9-b213-32cf3e6b0dd7",
            "a1969be7-c9a5-43f3-80c0-254d592e6747",
            "cd18f80a-0c6e-42b5-851b-4eed80ec0dff",
            "d3f23a97-7afc-4599-bae6-18143d721fd1",
            "77c94ac0-4de0-4bc8-8106-98b956fbb267",
            "431937e6-c98d-451f-8d1f-91d456590463",
            "7ecab67a-b007-4be7-af8c-cf0bc60c8366",
            "486e22d5-370e-4f12-8b64-c2283a8e89ee",
            "d60972a8-d6cc-49b0-870c-7b521cde7ffc",
            "0ed0b06a-02d7-4cdf-bf1b-7ab2cfb77ce8",
            "59b75ff9-0a74-463e-aeb0-8d8f8e614bad",
            "e80610c7-eb64-4392-baaa-cdf22d7ca994",
            "b1a85d5c-0590-4093-83db-ddf8cb4a3383",
            "8969ec82-deb9-4d61-9f0e-891345761e41",
            "8497766b-932c-4d78-8744-3f3e49c19433",
            "a71ae90d-0e2d-4cc9-967c-39fd3a3a8dc6",
            "09d07962-6337-4523-889c-cc15c378be37"
        ],
        "directions": [
            "inbound"
        ],
        "evaluationScore": {
            "gt": 0,
            "gte": 0,
            "lt": 0,
            "lte": 0
        },
        "evaluationCriticalScore": {
            "gt": 0,
            "gte": 0,
            "lt": 0,
            "lte": 0
        },
        "surveyTotalScore": {
            "gt": 0,
            "gte": 0,
            "lt": 0,
            "lte": 0
        },
        "surveyNpsScore": {
            "gt": 0,
            "gte": 0,
            "lt": 0,
            "lte": 0
        },
        "mos": {
            "gt": 0,
            "gte": 0,
            "lt": 0,
            "lte": 0
        },
        "surveyQuestionGroupScore": {
            "gt": 0,
            "gte": 0,
            "lt":0,
            "lte": 0
        },
        "surveyPromoterScore": {
            "gt": 0,
            "gte": 0,
            "lt": 0,
            "lte": 0
        },
        "isCampaign": True,
        "callbackInterval": "",
        "customerSentimentScore": {
            "gt": 100,
            "gte": 100,
            "lt": 100,
            "lte": 100
        },
        "customerSentimentTrend": {
            "gt": 0,
            "gte": 0,
            "lt": 0,
            "lte": 0
        },
        "developmentName": "",
        "botProviderList": [
            "Genesys"
        ],
        "actionCategoryName": "",
        "availableDashboard": "Private",
        "favouriteDashboard": True,
        "myDashboard": True,
        "subPath": "",
        "userState": "ActiveAndInactive",
        "divisionIds": [
            "f6cbd444-0b16-463e-a7b7-38a8b03a8562"
        ],
        "originatingDirections": [
            "inbound"
        ],
        "transferred": True,
        "abandoned": True,
        "answered": True
    },
    "locale": "pt-BR",
    "csvDelimiter": "SEMICOLON",
    "durationFormat": "Hhmmss",
    "name": "03-07-2024 Summary view",
    "interval": "2024-03-07T00:00:00/2024-03-07T23:59:00",
    "includeDurationFormatInHeader": True,
    "hasSummaryRow": True,
    "hasFormatDurations": True
    }
    try:
        response = requests.post(api_url, json=body, headers=headers)
        if response.status_code == 200:
            return response.json()
        else:
            print(f"Error in request: {response.status_code}")
            return None
    except Exception as e:
        print(f"Error calling API: {e}")
        return None

def main():
    client_id = "fba734fe-c75e-4a04-a0f9-c82557b5a1de"
    client_secret = "s5ut4GLMpjZwU1XS9AScJU-Hg8snlYMz44BeSqM-XvI"
    
    access_token = get_access_token(client_id, client_secret)
    if access_token:
        api_response = export_report(access_token)
        if api_response:
            pprint(api_response)

if __name__ == "__main__":
    main()
# Out:
# Error in request: 401

# %%
import requests
import json
import PureCloudPlatformClientV2
from PureCloudPlatformClientV2.rest import ApiException
from pprint import pprint
import base64

def get_access_token(client_id, client_secret):
    access_token_url = "https://login.sae1.pure.cloud/oauth/token"
    encoded_data = base64.b64encode(bytes(f"{client_id}:{client_secret}", "ISO-8859-1")).decode("ascii")
    authorization_header = f"Basic {encoded_data}"
    response = requests.post(access_token_url, headers={"Authorization": authorization_header}, data={'grant_type': 'client_credentials'})
    if response.status_code == 200:
        return response.json()['access_token']
    else:
        print(f"Failed to obtain access token: {response.status_code}")

def export_report(access_token):
    api_url = "https://api.mypurecloud.com/api/v2/analytics/reporting/exports"
    headers = {"Authorization": f"Bearer {access_token}", 'Content-Type': 'application/json'}
    body = {
    "timeZone": "Américas/São Paulo",
    "exportFormat": "CSV",
    "period": "P1D",
    "viewType": "QUEUE_PERFORMANCE_SUMMARY_VIEW",
    "filter": {
        "mediaTypes":[
            "voice"
        ],
        "queueIds": [
            "e4ed22cc-5878-46bd-a0c2-4d7fb20c0a15",
            "e3710d34-a7a5-44e6-8ed7-dd0c1d6ab77f",
            "518a0be0-d565-4057-bf4b-772ffe82c6b7",
            "67a86f91-ef50-44b9-b213-32cf3e6b0dd7",
            "a1969be7-c9a5-43f3-80c0-254d592e6747",
            "cd18f80a-0c6e-42b5-851b-4eed80ec0dff",
            "d3f23a97-7afc-4599-bae6-18143d721fd1",
            "77c94ac0-4de0-4bc8-8106-98b956fbb267",
            "431937e6-c98d-451f-8d1f-91d456590463",
            "7ecab67a-b007-4be7-af8c-cf0bc60c8366",
            "486e22d5-370e-4f12-8b64-c2283a8e89ee",
            "d60972a8-d6cc-49b0-870c-7b521cde7ffc",
            "0ed0b06a-02d7-4cdf-bf1b-7ab2cfb77ce8",
            "59b75ff9-0a74-463e-aeb0-8d8f8e614bad",
            "e80610c7-eb64-4392-baaa-cdf22d7ca994",
            "b1a85d5c-0590-4093-83db-ddf8cb4a3383",
            "8969ec82-deb9-4d61-9f0e-891345761e41",
            "8497766b-932c-4d78-8744-3f3e49c19433",
            "a71ae90d-0e2d-4cc9-967c-39fd3a3a8dc6",
            "09d07962-6337-4523-889c-cc15c378be37"
        ],
        "directions": [
            "inbound"
        ],
        "evaluationScore": {
            "gt": 0,
            "gte": 0,
            "lt": 0,
            "lte": 0
        },
        "evaluationCriticalScore": {
            "gt": 0,
            "gte": 0,
            "lt": 0,
            "lte": 0
        },
        "surveyTotalScore": {
            "gt": 0,
            "gte": 0,
            "lt": 0,
            "lte": 0
        },
        "surveyNpsScore": {
            "gt": 0,
            "gte": 0,
            "lt": 0,
            "lte": 0
        },
        "mos": {
            "gt": 0,
            "gte": 0,
            "lt": 0,
            "lte": 0
        },
        "surveyQuestionGroupScore": {
            "gt": 0,
            "gte": 0,
            "lt":0,
            "lte": 0
        },
        "surveyPromoterScore": {
            "gt": 0,
            "gte": 0,
            "lt": 0,
            "lte": 0
        },
        "isCampaign": True,
        "callbackInterval": "",
        "customerSentimentScore": {
            "gt": 100,
            "gte": 100,
            "lt": 100,
            "lte": 100
        },
        "customerSentimentTrend": {
            "gt": 0,
            "gte": 0,
            "lt": 0,
            "lte": 0
        },
        "developmentName": "",
        "botProviderList": [
            "Genesys"
        ],
        "actionCategoryName": "",
        "availableDashboard": "Private",
        "favouriteDashboard": True,
        "myDashboard": True,
        "subPath": "",
        "userState": "ActiveAndInactive",
        "divisionIds": [
            "f6cbd444-0b16-463e-a7b7-38a8b03a8562"
        ],
        "originatingDirections": [
            "inbound"
        ],
        "transferred": True,
        "abandoned": True,
        "answered": True
    },
    "locale": "pt-BR",
    "csvDelimiter": "SEMICOLON",
    "durationFormat": "Hhmmss",
    "name": "03-07-2024 Summary view",
    "interval": "2024-03-07T00:00:00/2024-03-07T23:59:00",
    "includeDurationFormatInHeader": True,
    "hasSummaryRow": True,
    "hasFormatDurations": True
    }
 
    try:
        response = requests.post(api_url, json=body, headers=headers)
        response.raise_for_status()  # Raise an exception for 4xx/5xx status codes
        if response.status_code == 200:
            return response.json()
        else:
            print(f"Error in request: {response.status_code}")
            return None
    except requests.exceptions.RequestException as e:
        print(f"Error calling API: {e}")
        return None

def main():
    client_id = "fba734fe-c75e-4a04-a0f9-c82557b5a1de"
    client_secret = "s5ut4GLMpjZwU1XS9AScJU-Hg8snlYMz44BeSqM-XvI"
    
    access_token = get_access_token(client_id, client_secret)
    if access_token:
        api_response = export_report(access_token)
        if api_response:
            pprint(api_response)

if __name__ == "__main__":
    main()
# Out:
# Error calling API: 401 Client Error: Unauthorized for url: https://api.mypurecloud.com/api/v2/analytics/reporting/exports

# %%
import base64
import json
import requests

def get_access_token(client_id, client_secret):
    access_token_url = "https://login.sae1.pure.cloud/oauth/token"
    encoded_data = base64.b64encode(bytes(f"{client_id}:{client_secret}", "ISO-8859-1")).decode("ascii")
    authorization_header = f"Basic {encoded_data}"
    response = requests.post(access_token_url, headers={"Authorization": authorization_header}, data={'grant_type': 'client_credentials'})
    if response.status_code == 200:
        return response.json()['access_token']
    else:
        print(f"Failed to obtain access token: {response.status_code}")

def export_report(access_token):
    api_url = "https://api.mypurecloud.com/api/v2/analytics/reporting/exports"
    headers = {"Authorization": f"Bearer {access_token}", 'Content-Type': 'application/json'}
    body = {
    "timeZone": "Américas/São Paulo",
    "exportFormat": "CSV",
    "period": "P1D",
    "viewType": "QUEUE_PERFORMANCE_SUMMARY_VIEW",
    "filter": {
        "mediaTypes":[
            "voice"
        ],
        "queueIds": [
            "e4ed22cc-5878-46bd-a0c2-4d7fb20c0a15",
            "e3710d34-a7a5-44e6-8ed7-dd0c1d6ab77f",
            "518a0be0-d565-4057-bf4b-772ffe82c6b7",
            "67a86f91-ef50-44b9-b213-32cf3e6b0dd7",
            "a1969be7-c9a5-43f3-80c0-254d592e6747",
            "cd18f80a-0c6e-42b5-851b-4eed80ec0dff",
            "d3f23a97-7afc-4599-bae6-18143d721fd1",
            "77c94ac0-4de0-4bc8-8106-98b956fbb267",
            "431937e6-c98d-451f-8d1f-91d456590463",
            "7ecab67a-b007-4be7-af8c-cf0bc60c8366",
            "486e22d5-370e-4f12-8b64-c2283a8e89ee",
            "d60972a8-d6cc-49b0-870c-7b521cde7ffc",
            "0ed0b06a-02d7-4cdf-bf1b-7ab2cfb77ce8",
            "59b75ff9-0a74-463e-aeb0-8d8f8e614bad",
            "e80610c7-eb64-4392-baaa-cdf22d7ca994",
            "b1a85d5c-0590-4093-83db-ddf8cb4a3383",
            "8969ec82-deb9-4d61-9f0e-891345761e41",
            "8497766b-932c-4d78-8744-3f3e49c19433",
            "a71ae90d-0e2d-4cc9-967c-39fd3a3a8dc6",
            "09d07962-6337-4523-889c-cc15c378be37"
        ],
        "directions": [
            "inbound"
        ],
        "evaluationScore": {
            "gt": 0,
            "gte": 0,
            "lt": 0,
            "lte": 0
        },
        "evaluationCriticalScore": {
            "gt": 0,
            "gte": 0,
            "lt": 0,
            "lte": 0
        },
        "surveyTotalScore": {
            "gt": 0,
            "gte": 0,
            "lt": 0,
            "lte": 0
        },
        "surveyNpsScore": {
            "gt": 0,
            "gte": 0,
            "lt": 0,
            "lte": 0
        },
        "mos": {
            "gt": 0,
            "gte": 0,
            "lt": 0,
            "lte": 0
        },
        "surveyQuestionGroupScore": {
            "gt": 0,
            "gte": 0,
            "lt":0,
            "lte": 0
        },
        "surveyPromoterScore": {
            "gt": 0,
            "gte": 0,
            "lt": 0,
            "lte": 0
        },
        "isCampaign": True,
        "callbackInterval": "",
        "customerSentimentScore": {
            "gt": 100,
            "gte": 100,
            "lt": 100,
            "lte": 100
        },
        "customerSentimentTrend": {
            "gt": 0,
            "gte": 0,
            "lt": 0,
            "lte": 0
        },
        "developmentName": "",
        "botProviderList": [
            "Genesys"
        ],
        "actionCategoryName": "",
        "availableDashboard": "Private",
        "favouriteDashboard": True,
        "myDashboard": True,
        "subPath": "",
        "userState": "ActiveAndInactive",
        "divisionIds": [
            "f6cbd444-0b16-463e-a7b7-38a8b03a8562"
        ],
        "originatingDirections": [
            "inbound"
        ],
        "transferred": True,
        "abandoned": True,
        "answered": True
    },
    "locale": "pt-BR",
    "csvDelimiter": "SEMICOLON",
    "durationFormat": "Hhmmss",
    "name": "03-07-2024 Summary view",
    "interval": "2024-03-07T00:00:00/2024-03-07T23:59:00",
    "includeDurationFormatInHeader": True,
    "hasSummaryRow": True,
    "hasFormatDurations": True
    }
    

    try:
        response = requests.post(api_url, json=body, headers=headers)
        response.raise_for_status()
        if response.status_code == 200:
            return response.json()
        else:
            print(f"Error in request: {response.status_code}")
            return None
    except requests.exceptions.RequestException as e:
        print(f"Error calling API: {e}")
        return None

if __name__ == "__main__":
    client_id = "fba734fe-c75e-4a04-a0f9-c82557b5a1de"
    client_secret = "s5ut4GLMpjZwU1XS9AScJU-Hg8snlYMz44BeSqM-XvI"

    access_token = get_access_token(client_id, client_secret)
    if access_token:
        api_response = export_report(access_token)
        if api_response:
            print(json.dumps(api_response, indent=2))
# Out:
# Error calling API: 401 Client Error: Unauthorized for url: https://api.mypurecloud.com/api/v2/analytics/reporting/exports
